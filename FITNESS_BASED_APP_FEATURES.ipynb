# %% [markdown]
# #**MIND SECTION**
#
# *   Personalized Meditation & Breathwork
# *   Cognitive Skill Training
# *   Focus Mode with Environmental AI: music/ pomodoro
# *   AI Therapy Companion (chatbot)
# *   Audio Emotion Logger

# %%
# !pip install streamlit pyngrok --quiet
# !echo "auth_token: your_ngrok_token" > ~/.streamlit/secrets.toml  # optional
# !streamlit run app_mind.py & npx localtunnel --port 8501
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 40.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 54.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.9 MB/s eta 0:00:00
# /bin/bash: line 1: /root/.streamlit/secrets.toml: No such file or directory
# ⠙Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app_mind.py
# ⠹⠸⠼⠴⠦⠧Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) ^C

# %%
# app_mind.py
import streamlit as st
import time
import random
import datetime

st.set_page_config(page_title="MIND - Wellness", layout="centered")

st.title("🧘 MIND - Mental Fitness Suite")

# 1. Personalized Meditation
st.header("1. Personalized Meditation & Breathwork")
mood = st.selectbox("How are you feeling right now?", ["Stressed", "Anxious", "Tired", "Calm"])
duration = st.slider("How long do you want to meditate?", 5, 30, 10)

if st.button("Generate Meditation"):
    st.success(f"Here’s your {duration}-minute session for feeling {mood}:")
    if mood == "Stressed":
        st.write("👉 Box Breathing: Inhale 4s, Hold 4s, Exhale 4s, Hold 4s")
    elif mood == "Anxious":
        st.write("👉 4-7-8 Breathing: Inhale 4s, Hold 7s, Exhale 8s")
    elif mood == "Tired":
        st.write("👉 Energizing Breath: Short inhales, forceful exhales")
    else:
        st.write("👉 Mindfulness Scan: Focus attention on each body part")

# 2. Cognitive Training - Simple Brain Game
st.header("2. Brain Game: Memory Match")
if st.button("Start Game"):
    number = random.randint(100, 999)
    st.session_state['memory'] = number
    st.write("💡 Memorize this number:", number)
    time.sleep(3)
    st.empty()
    guess = st.text_input("What was the number?")
    if guess:
        if guess == str(st.session_state.get('memory')):
            st.success("Correct! 🧠 Great memory!")
        else:
            st.error(f"Oops! It was {st.session_state.get('memory')}")

# 3. Focus Mode (Pomodoro)
st.header("3. Focus Mode 🎧")
focus_time = st.number_input("Focus Time (minutes)", 5, 60, 25)
start_focus = st.button("Start Focus Session")

if start_focus:
    st.success(f"Focus for {focus_time} minutes. Play ambient music in another tab.")
    st.audio("https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3")
    st.write("⏳ Timer running... (start your task and focus)")
    time.sleep(2)

# 4. AI Therapy Companion (Simulated)
st.header("4. AI Therapy Companion 💬")
st.write("💡 This is a basic chat simulation.")

if "chat_history" not in st.session_state:
    st.session_state.chat_history = []

user_input = st.text_input("You:")
if user_input:
    st.session_state.chat_history.append(("You", user_input))
    # Simulated response
    response = "Thanks for sharing. Can you tell me more about how that makes you feel?"
    st.session_state.chat_history.append(("Therapist", response))

for speaker, msg in st.session_state.chat_history:
    st.markdown(f"**{speaker}:** {msg}")

# 5. Audio Emotion Logger (Simulated)
st.header("5. 🎤 Audio Emotion Logger (Simulated)")
audio_file = st.file_uploader("Upload a voice recording", type=["wav", "mp3"])

if audio_file:
    st.audio(audio_file, format="audio/wav")
    # Simulate detection (in reality, you'd use a model)
    detected_emotion = random.choice(["Happy", "Sad", "Angry", "Calm", "Anxious"])
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    st.success(f"🧠 Detected Emotion: {detected_emotion} at {timestamp}")

    if "emotion_log" not in st.session_state:
        st.session_state.emotion_log = []
    st.session_state.emotion_log.append((timestamp, detected_emotion))

if "emotion_log" in st.session_state and st.session_state.emotion_log:
    st.subheader("📘 Emotion Log History")
    for ts, emo in reversed(st.session_state.emotion_log[-5:]):
        st.write(f"{ts} - {emo}")
# Out:
# 2025-05-11 05:25:51.484 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.487 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.718
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-05-11 05:25:51.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.732 Session state does not function when running a script without `streamlit run`
# 2025-05-11 05:25:51.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 05:25:51.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
